# %% [markdown]
# This notebook attempts rotation as implemented in [this Monai tutorial](https://colab.research.google.com/github/Project-MONAI/tutorials/blob/master/modules/3d_image_transforms.ipynb#scrollTo=soJiHn_Wj6gy)

# %%
import matplotlib.pyplot as plt
import nibabel as nib
import nilearn as nil
import scipy.ndimage as ndi
import matplotlib.pyplot as plt
import os
import numpy as np
import monai

import torch
from torch.utils.data import DataLoader

from nibabel import save
from nilearn import image
from nilearn.image import get_data
from nilearn.plotting import show

from monai.transforms import (
    EnsureChannelFirstd,
    LoadImaged,
    BorderPadd,
    RandAffined,
    Affined,
    EnsureChannelFirstd,
    Compose,
    LoadImaged,
    SaveImaged,
    ScaleIntensityd,
)
from monai.config import print_config
from monai.apps import download_and_extract
from monai.utils import set_determinism, first

import os
import shutil
import glob as glob

print_config()
# Out:
# MONAI version: 1.2.0
# Numpy version: 1.25.0
# Pytorch version: 2.0.1
# MONAI flags: HAS_EXT = False, USE_COMPILED = False, USE_META_DICT = False
# MONAI rev id: c33f1ba588ee00229a309000e888f9817b4f1934
# MONAI __file__: /home/chloe/.conda/envs/torch/lib/python3.11/site-packages/monai/__init__.py
#
# Optional dependencies:
# Pytorch Ignite version: NOT INSTALLED or UNKNOWN VERSION.
# ITK version: 5.3.0
# Nibabel version: 5.1.0
# scikit-image version: 0.20.0
# Pillow version: 9.4.0
# Tensorboard version: NOT INSTALLED or UNKNOWN VERSION.
# gdown version: NOT INSTALLED or UNKNOWN VERSION.
# TorchVision version: 0.15.2
# tqdm version: 4.65.0
# lmdb version: NOT INSTALLED or UNKNOWN VERSION.
# psutil version: 5.9.0
# pandas version: 1.5.3
# einops version: NOT INSTALLED or UNKNOWN VERSION.
# transformers version: NOT INSTALLED or UNKNOWN VERSION.
# mlflow version: NOT INSTALLED or UNKNOWN VERSION.
# pynrrd version: NOT INSTALLED or UNKNOWN VERSION.
#
# For details about installing the optional dependencies, please visit:
#     https://docs.monai.io/en/latest/installation.html#installing-the-recommended-dependencies
#
# Numpy version: 1.25.0
# Pytorch version: 2.0.1
# MONAI flags: HAS_EXT = False, USE_COMPILED = False, USE_META_DICT = False
# MONAI rev id: c33f1ba588ee00229a309000e888f9817b4f1934
# MONAI __file__: /home/chloe/.conda/envs/torch/lib/python3.11/site-packages/monai/__init__.py
#
# Optional dependencies:
# Pytorch Ignite version: NOT INSTALLED or UNKNOWN VERSION.
# ITK version: 5.3.0
# Nibabel version: 5.1.0
# scikit-image version: 0.20.0
# Pillow version: 9.4.0
# Tensorboard version: NOT INSTALLED or UNKNOWN VERSION.
# gdown version: NOT INSTALLED or UNKNOWN VERSION.
# TorchVision version: 0.15.2
# tqdm version: 4.65.0
# lmdb version: NOT INSTALLED or UNKNOWN VERSION.
# psutil version: 5.9.0
# pandas version: 1.5.3
# einops version: NOT INSTALLED or UNKNOWN VERSION.
# transformers version: NOT INSTALLED or UNKNOWN VERSION.
# mlflow version: NOT INSTALLED or UNKNOWN VERSION.
# pynrrd version: NOT INSTALLED or UNKNOWN VERSION.
#
# For details about installing the optional dependencies, please visit:
#     https://docs.monai.io/en/latest/installation.html#installing-the-recommended-dependencies

# %% [markdown]
# Create dataset path and dictionary

# %%
data_dir = "data/"

train_images = sorted(glob.glob(os.path.join(data_dir, "imagesTs", "*.nii.gz")))
train_labels = sorted(glob.glob(os.path.join(data_dir, "labelsTs", "*.nii.gz")))
data_dicts = [{"image": image_name, "label": label_name} for image_name, label_name in zip(train_images, train_labels)]

# %% [markdown]
# Load the images to visualize a sampling and get data dimensions

# %%
dimensions = np.zeros([len(data_dicts),3])

for index in range(len(data_dicts)):
    img_path = data_dicts[index]['image']
    lbl_path = data_dicts[index]['label']
    before_rot = image.load_img(img_path)
    before_rot_label = image.load_img(lbl_path)
    dimension = before_rot.shape
    dimensions[index] = dimension

    center = np.divide(dimension,2)
    x_cen = int(np.ceil(center[0]))
    y_cen = int(np.ceil(center[1]))
    z_cen = int(np.ceil(center[2]))

    fig = plt.figure("visualize", (len(data_dicts), 3))
    fig.set_size_inches(10,3)
    plt.subplot(1, 3, 1)
    plt.title(f"Slice through x-center ")
    plt.imshow(get_data(before_rot)[x_cen, :, :])
    plt.subplot(1, 3, 2)
    plt.title(f"Slice through y-center ")
    plt.imshow(get_data(before_rot)[:, y_cen, :])
    plt.subplot(1, 3, 3)
    plt.title(f"Slice through z-center")
    plt.imshow(get_data(before_rot)[:, :, z_cen])
    plt.show()

    fig = plt.figure("labels", (len(data_dicts), 3))
    fig.set_size_inches(10,3)
    plt.subplot(1, 3, 1)
    plt.title(f"Slice through x-center ")
    plt.imshow(get_data(before_rot_label)[x_cen, :, :])
    plt.subplot(1, 3, 2)
    plt.title(f"Slice through y-center ")
    plt.imshow(get_data(before_rot_label)[:, y_cen, :])
    plt.subplot(1, 3, 3)
    plt.title(f"Slice through z-center ")
    plt.imshow(get_data(before_rot_label)[:, :, z_cen])
    plt.show()

# %% [markdown]
# Visualize all the dimensions

# %%
print(dimensions)
# Out:
# [[512. 512. 196.]
#  [512. 512. 229.]
#  [512. 512. 217.]
#  [512. 512. 158.]
#  [512. 512. 197.]
#  [512. 512. 197.]
#  [512. 512. 194.]
#  [512. 512. 205.]
#  [512. 512. 223.]
#  [512. 512. 209.]
#  [512. 512. 196.]
#  [512. 512. 175.]
#  [512. 512. 188.]
#  [512. 512. 218.]
#  [512. 512. 193.]
#  [512. 512. 202.]]

# %% [markdown]
# Set axis of rotation:
# - x = 0
# - y = 1
# - z = 2
#
# Set starting degree, ending degree of rotation, and rotation step.
#
# This code will produce rotations increaseing from starting degree to ending degree with step of chosen degree (ensure this divides evenly).
#
# For control experiment, only rotating with zero degree.

# %%
axis = 2

start_deg = 0
end_deg = 0
step = 1

if (start_deg - end_deg)%step != 0:
    print("Step does not divide evenly: choose different rotation parameters.")

# %% [markdown]
# Loop over all rotations: Use get_dim_about_z notebook in order to get x,y dimensions using your maximum rotation. For rotations between -30 to 30 degrees, we have a maximum x and y dimension of 585. We are using same set dist and protocol from general rotations as the control group. We are using the same z value as given in the original image.

# %%
set_dist = 585

deg_array = np.zeros(3)
deg_array[axis] = start_deg - step

#Loop over specified range of degrees
while deg_array[axis] < end_deg:

    #Set degree for iteration
    deg_array[axis] = deg_array[axis] + step
    deg_array_rad = np.deg2rad(deg_array)

    a, b, c = deg_array[0], deg_array[1], deg_array[2]
    a_rad, b_rad, c_rad = deg_array_rad[0], deg_array_rad[1], deg_array_rad[2]

    #Create folders to store control images and labels
    image_path = f'results/control_results/control_images/' 
    if not os.path.exists(image_path):
        os.makedirs(image_path)

    label_path = f'results/control_results/control_labels/' 
    if not os.path.exists(label_path):
        os.makedirs(label_path)

    #Produce control image with maximum padding for each image
    for index in range(len(data_dicts)):
        data_transform = Compose(
            [
                LoadImaged(keys=["image", "label"]),
                EnsureChannelFirstd(keys=["image", "label"]),
                BorderPadd(keys=["image"],
                        spatial_border = 1, 
                        mode='constant', 
                        lazy=False, 
                        constant_values = -1024),
                BorderPadd(keys=["label"],
                        spatial_border = 1, 
                        mode='constant', 
                        lazy=False,
                        constant_values = 0),
                Affined(keys=["image", "label"],
                    rotate_params = (a_rad, b_rad, c_rad),
                    mode=('bilinear','nearest'),
                    padding_mode=('border'),
                    spatial_size = (set_dist, set_dist, -1),
                    align_corners = True
                ),
                SaveImaged(keys=["image"],
                    output_dir=image_path, 
                    output_postfix =  f"control_image_{a}_{b}_{c}_0000",
                    output_ext=".nii.gz",
                    resample = False),
                SaveImaged(keys=["label"],
                    output_dir=label_path, 
                    output_postfix =  f"control_label_{a}_{b}_{c}",
                    output_ext=".nii.gz",
                    resample = False),
            ])

        #Runs transformation with specified shape
        transformed_data_dict = data_transform(data_dicts[index])
# Out:
# monai.transforms.io.dictionary LoadImaged.__init__:image_only: Current default value of argument `image_only=False` has been deprecated since version 1.1. It will be changed to `image_only=True` in version 1.3.
# 2023-08-16 18:33:26,644 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_images/HN_P002_pre_0000/HN_P002_pre_0000_control_image_0.0_0.0_0.0_0000.nii.gz
# 2023-08-16 18:33:32,168 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_labels/HN_P002_pre/HN_P002_pre_control_label_0.0_0.0_0.0.nii.gz
# 2023-08-16 18:33:45,718 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_images/HN_P003_pre_0000/HN_P003_pre_0000_control_image_0.0_0.0_0.0_0000.nii.gz
# 2023-08-16 18:33:52,181 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_labels/HN_P003_pre/HN_P003_pre_control_label_0.0_0.0_0.0.nii.gz
# 2023-08-16 18:34:05,406 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_images/HN_P005_pre_0000/HN_P005_pre_0000_control_image_0.0_0.0_0.0_0000.nii.gz
# 2023-08-16 18:34:11,154 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_labels/HN_P005_pre/HN_P005_pre_control_label_0.0_0.0_0.0.nii.gz
# 2023-08-16 18:34:20,704 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_images/HN_P007_pre_0000/HN_P007_pre_0000_control_image_0.0_0.0_0.0_0000.nii.gz
# 2023-08-16 18:34:25,259 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_labels/HN_P007_pre/HN_P007_pre_control_label_0.0_0.0_0.0.nii.gz
# 2023-08-16 18:34:36,557 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_images/HN_P008_pre_0000/HN_P008_pre_0000_control_image_0.0_0.0_0.0_0000.nii.gz
# 2023-08-16 18:34:41,779 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_labels/HN_P008_pre/HN_P008_pre_control_label_0.0_0.0_0.0.nii.gz
# 2023-08-16 18:34:53,082 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_images/HN_P009_pre_0000/HN_P009_pre_0000_control_image_0.0_0.0_0.0_0000.nii.gz
# 2023-08-16 18:34:58,386 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_labels/HN_P009_pre/HN_P009_pre_control_label_0.0_0.0_0.0.nii.gz
# 2023-08-16 18:35:09,933 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_images/HN_P010_pre_0000/HN_P010_pre_0000_control_image_0.0_0.0_0.0_0000.nii.gz
# 2023-08-16 18:35:14,776 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_labels/HN_P010_pre/HN_P010_pre_control_label_0.0_0.0_0.0.nii.gz
# 2023-08-16 18:35:27,063 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_images/HN_P011_pre_0000/HN_P011_pre_0000_control_image_0.0_0.0_0.0_0000.nii.gz
# 2023-08-16 18:35:32,845 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_labels/HN_P011_pre/HN_P011_pre_control_label_0.0_0.0_0.0.nii.gz
# 2023-08-16 18:35:46,199 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_images/HN_P014_pre_0000/HN_P014_pre_0000_control_image_0.0_0.0_0.0_0000.nii.gz
# 2023-08-16 18:35:51,918 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_labels/HN_P014_pre/HN_P014_pre_control_label_0.0_0.0_0.0.nii.gz
# 2023-08-16 18:36:04,659 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_images/HN_P016_pre_0000/HN_P016_pre_0000_control_image_0.0_0.0_0.0_0000.nii.gz
# 2023-08-16 18:36:09,881 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_labels/HN_P016_pre/HN_P016_pre_control_label_0.0_0.0_0.0.nii.gz
# 2023-08-16 18:36:21,805 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_images/HN_P018_pre_0000/HN_P018_pre_0000_control_image_0.0_0.0_0.0_0000.nii.gz
# 2023-08-16 18:36:27,028 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_labels/HN_P018_pre/HN_P018_pre_control_label_0.0_0.0_0.0.nii.gz
# 2023-08-16 18:36:37,353 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_images/HN_P020_pre_0000/HN_P020_pre_0000_control_image_0.0_0.0_0.0_0000.nii.gz
# 2023-08-16 18:36:41,822 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_labels/HN_P020_pre/HN_P020_pre_control_label_0.0_0.0_0.0.nii.gz
# 2023-08-16 18:36:52,801 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_images/HN_P022_pre_0000/HN_P022_pre_0000_control_image_0.0_0.0_0.0_0000.nii.gz
# 2023-08-16 18:36:57,668 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_labels/HN_P022_pre/HN_P022_pre_control_label_0.0_0.0_0.0.nii.gz
# 2023-08-16 18:37:14,167 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_images/HN_P027_pre_0000/HN_P027_pre_0000_control_image_0.0_0.0_0.0_0000.nii.gz
# 2023-08-16 18:37:20,804 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_labels/HN_P027_pre/HN_P027_pre_control_label_0.0_0.0_0.0.nii.gz
# 2023-08-16 18:37:35,211 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_images/HN_P033_pre_0000/HN_P033_pre_0000_control_image_0.0_0.0_0.0_0000.nii.gz
# 2023-08-16 18:37:40,770 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_labels/HN_P033_pre/HN_P033_pre_control_label_0.0_0.0_0.0.nii.gz
# 2023-08-16 18:37:56,155 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_images/HN_P035_pre_0000/HN_P035_pre_0000_control_image_0.0_0.0_0.0_0000.nii.gz
# 2023-08-16 18:38:02,068 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_labels/HN_P035_pre/HN_P035_pre_control_label_0.0_0.0_0.0.nii.gz

# %% [markdown]
# Create images transformed by only loading and saving

# %%
#Create folders to store control images and labels
image_path = f'results/control_results/control_images/' 
if not os.path.exists(image_path):
    os.makedirs(image_path)

label_path = f'results/control_results/control_labels/' 
if not os.path.exists(label_path):
    os.makedirs(label_path)

#Produce control image with maximum padding for each image
for index in range(len(data_dicts)):
    data_transform = Compose(
        [
            LoadImaged(keys=["image", "label"]),
            SaveImaged(keys=["image"],
                output_dir=image_path, 
                output_postfix =  f"load_save_image_{a}_{b}_{c}_0000",
                output_ext=".nii.gz",
                resample = False),
            SaveImaged(keys=["label"],
                output_dir=label_path, 
                output_postfix =  f"load_save_label_{a}_{b}_{c}",
                output_ext=".nii.gz",
                resample = False),
        ])

    #Runs transformation with specified shape
    transformed_data_dict = data_transform(data_dicts[index])
# Out:
# 2023-08-16 10:39:31,881 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_images/HN_P002_pre_0000/HN_P002_pre_0000_load_save_image_0.0_0.0_0.0_0000.nii.gz
# 2023-08-16 10:39:34,660 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_labels/HN_P002_pre/HN_P002_pre_load_save_label_0.0_0.0_0.0.nii.gz
# 2023-08-16 10:39:49,916 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_images/HN_P003_pre_0000/HN_P003_pre_0000_load_save_image_0.0_0.0_0.0_0000.nii.gz
# 2023-08-16 10:39:53,119 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_labels/HN_P003_pre/HN_P003_pre_load_save_label_0.0_0.0_0.0.nii.gz
# 2023-08-16 10:40:07,657 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_images/HN_P005_pre_0000/HN_P005_pre_0000_load_save_image_0.0_0.0_0.0_0000.nii.gz
# 2023-08-16 10:40:10,450 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_labels/HN_P005_pre/HN_P005_pre_load_save_label_0.0_0.0_0.0.nii.gz
# 2023-08-16 10:40:20,498 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_images/HN_P007_pre_0000/HN_P007_pre_0000_load_save_image_0.0_0.0_0.0_0000.nii.gz
# 2023-08-16 10:40:22,748 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_labels/HN_P007_pre/HN_P007_pre_load_save_label_0.0_0.0_0.0.nii.gz
# 2023-08-16 10:40:35,527 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_images/HN_P008_pre_0000/HN_P008_pre_0000_load_save_image_0.0_0.0_0.0_0000.nii.gz
# 2023-08-16 10:40:38,078 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_labels/HN_P008_pre/HN_P008_pre_load_save_label_0.0_0.0_0.0.nii.gz
# 2023-08-16 10:40:50,798 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_images/HN_P009_pre_0000/HN_P009_pre_0000_load_save_image_0.0_0.0_0.0_0000.nii.gz
# 2023-08-16 10:40:53,509 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_labels/HN_P009_pre/HN_P009_pre_load_save_label_0.0_0.0_0.0.nii.gz
# 2023-08-16 10:41:06,372 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_images/HN_P010_pre_0000/HN_P010_pre_0000_load_save_image_0.0_0.0_0.0_0000.nii.gz
# 2023-08-16 10:41:08,791 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_labels/HN_P010_pre/HN_P010_pre_load_save_label_0.0_0.0_0.0.nii.gz
# 2023-08-16 10:41:21,970 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_images/HN_P011_pre_0000/HN_P011_pre_0000_load_save_image_0.0_0.0_0.0_0000.nii.gz
# 2023-08-16 10:41:24,988 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_labels/HN_P011_pre/HN_P011_pre_load_save_label_0.0_0.0_0.0.nii.gz
# 2023-08-16 10:41:39,657 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_images/HN_P014_pre_0000/HN_P014_pre_0000_load_save_image_0.0_0.0_0.0_0000.nii.gz
# 2023-08-16 10:41:42,624 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_labels/HN_P014_pre/HN_P014_pre_load_save_label_0.0_0.0_0.0.nii.gz
# 2023-08-16 10:41:56,193 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_images/HN_P016_pre_0000/HN_P016_pre_0000_load_save_image_0.0_0.0_0.0_0000.nii.gz
# 2023-08-16 10:41:58,802 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_labels/HN_P016_pre/HN_P016_pre_load_save_label_0.0_0.0_0.0.nii.gz
# 2023-08-16 10:42:12,387 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_images/HN_P018_pre_0000/HN_P018_pre_0000_load_save_image_0.0_0.0_0.0_0000.nii.gz
# 2023-08-16 10:42:15,017 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_labels/HN_P018_pre/HN_P018_pre_load_save_label_0.0_0.0_0.0.nii.gz
# 2023-08-16 10:42:26,268 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_images/HN_P020_pre_0000/HN_P020_pre_0000_load_save_image_0.0_0.0_0.0_0000.nii.gz
# 2023-08-16 10:42:28,551 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_labels/HN_P020_pre/HN_P020_pre_load_save_label_0.0_0.0_0.0.nii.gz
# 2023-08-16 10:42:39,962 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_images/HN_P022_pre_0000/HN_P022_pre_0000_load_save_image_0.0_0.0_0.0_0000.nii.gz
# 2023-08-16 10:42:42,435 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_labels/HN_P022_pre/HN_P022_pre_load_save_label_0.0_0.0_0.0.nii.gz
# 2023-08-16 10:42:56,944 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_images/HN_P027_pre_0000/HN_P027_pre_0000_load_save_image_0.0_0.0_0.0_0000.nii.gz
# 2023-08-16 10:43:00,268 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_labels/HN_P027_pre/HN_P027_pre_load_save_label_0.0_0.0_0.0.nii.gz
# 2023-08-16 10:43:12,527 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_images/HN_P033_pre_0000/HN_P033_pre_0000_load_save_image_0.0_0.0_0.0_0000.nii.gz
# 2023-08-16 10:43:15,270 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_labels/HN_P033_pre/HN_P033_pre_load_save_label_0.0_0.0_0.0.nii.gz
# 2023-08-16 10:43:28,455 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_images/HN_P035_pre_0000/HN_P035_pre_0000_load_save_image_0.0_0.0_0.0_0000.nii.gz
# 2023-08-16 10:43:31,393 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_04/results/control_results/control_labels/HN_P035_pre/HN_P035_pre_load_save_label_0.0_0.0_0.0.nii.gz

# %% [markdown]
# Copy control images (0 rot with padding) and load_save images into nnUnet folder for testing

# %%
# Define the path to where you store transformed data and where to store nnUnet data
transform_image_dir = 'results/control_results/control_images'
nnUnet_data_path = '/home/chloe/nnUNet_raw_data_base/nnUNet_raw_data/Task603_SettingUp/imagesTs' #Change to your nnUnet data path

# Code to move transformed data from subfolders to single folder
patient_names = os.listdir(transform_image_dir)
for patient in patient_names:
    patient_path = os.path.join(transform_image_dir, patient)
    image_names = os.listdir(patient_path)
    for image in image_names:
        image_path = os.path.join(patient_path, image)
        shutil.copy(image_path, nnUnet_data_path)

print("Files copied")
# Out:
# Files copied

# %% [markdown]
# Copy original Images into nnUnet folder for testing

# %%
# Define the path to where you store original data and where to store nnUnet data
original_image_dir = 'data/imagesTs'

# Code to move transformed data from subfolders to single folder
patient_images = os.listdir(original_image_dir)
for patient in patient_images:
    patient_path = os.path.join(original_image_dir, patient)
    shutil.copy(patient_path, nnUnet_data_path)

print("Files copied")
# Out:
# Files copied

# %% [markdown]
# Visualize the control group (padding with no rotation)

# %%
from nilearn import image

image_path = 'results/control_results/control_images'
label_path = 'results/control_results/control_labels'
for index in range(len(data_dicts)):
    a, b, c = 0.0, 0.0, 0.0
    img_str = data_dicts[index]['image'].strip("data/imagesTs/").strip(".nii.gz")
    lbl_str = data_dicts[index]['image'].strip("data/imagesTs/").strip("_0000.nii.gz")
    img_path = image_path + "/" + img_str + "/" + img_str + f"_control_image_{a}_{b}_{c}_0000" + '.nii.gz'
    lbl_path = label_path + "/" +lbl_str + "/" + lbl_str + f"_control_label_{a}_{b}_{c}" + '.nii.gz'
    after_rot = image.load_img(img_path)
    after_rot_label = image.load_img(lbl_path)
    dimension = after_rot.shape

    center = np.divide(dimension,2)
    x_cen = int(np.ceil(center[0]))
    y_cen = int(np.ceil(center[1]))
    z_cen = int(np.ceil(center[2]))

    fig = plt.figure("visualize", (len(data_dicts), 3))
    fig.set_size_inches(10,3)
    plt.subplot(1, 3, 1)
    plt.title(f"Slice through x-center ")
    plt.imshow(get_data(after_rot)[x_cen, :, :])
    plt.subplot(1, 3, 2)
    plt.title(f"Slice through y-center ")
    plt.imshow(get_data(after_rot)[:, y_cen, :])
    plt.subplot(1, 3, 3)
    plt.title(f"Slice through z-center")
    plt.imshow(get_data(after_rot)[:, :, z_cen])
    plt.show()

    fig = plt.figure("labels", (len(data_dicts), 3))
    fig.set_size_inches(10,3)
    plt.subplot(1, 3, 1)
    plt.title(f"Slice through x-center ")
    plt.imshow(get_data(after_rot_label)[x_cen, :, :])
    plt.subplot(1, 3, 2)
    plt.title(f"Slice through y-center ")
    plt.imshow(get_data(after_rot_label)[:, y_cen, :])
    plt.subplot(1, 3, 3)
    plt.title(f"Slice through z-center ")
    plt.imshow(get_data(after_rot_label)[:, :, z_cen])
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 9
#       7 img_path = image_path + "/" + img_str + "/" + img_str + f"_control_image_{a}_{b}_{c}_0000" + '.nii.gz'
#       8 lbl_path = label_path + "/" +lbl_str + "/" + lbl_str + f"_control_label_{a}_{b}_{c}" + '.nii.gz'
# ----> 9 after_rot = image.load_img(img_path)
#      10 after_rot_label = image.load_img(lbl_path)
#      11 dimension = after_rot.shape
#
# File ~/.conda/envs/torch/lib/python3.11/site-packages/nilearn/image/image.py:1333, in load_img(img, wildcards, dtype)
#    1295 def load_img(img, wildcards=True, dtype=None):
#    1296     """Load a Niimg-like object from filenames or list of filenames.
#    1297
#    1298     .. versionadded:: 0.2.5
#    (...)
#    1331
#    1332     """
# -> 1333     return check_niimg(img, wildcards=wildcards, dtype=dtype)
#
# File ~/.conda/envs/torch/lib/python3.11/site-packages/nilearn/_utils/niimg_conversions.py:303, in check_niimg(niimg, ensure_ndim, atleast_4d, dtype, return_iterator, wildcards)
#     301         raise ValueError(message)
#     302     else:
# --> 303         raise ValueError(f"File not found: '{niimg}'")
#     304 elif not os.path.exists(niimg):
#     305     raise ValueError(f"File not found: '{niimg}'")
#
# ValueError: File not found: '/home/chloe/research/code/inference_04/results/control_results/control_images/HN_P002_pre_0000/HN_P002_pre_0000_control_image_0.0_0.0_0_0000.nii.gz'
