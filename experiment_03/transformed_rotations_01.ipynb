# %% [markdown]
# This notebook attempts rotation as implemented in [this Monai tutorial](https://colab.research.google.com/github/Project-MONAI/tutorials/blob/master/modules/3d_image_transforms.ipynb#scrollTo=soJiHn_Wj6gy)

# %%
import matplotlib.pyplot as plt
import nibabel as nib
import nilearn as nil
import scipy.ndimage as ndi
import matplotlib.pyplot as plt
import os
import numpy as np
import monai

import torch
from torch.utils.data import DataLoader

from nibabel import save
from nilearn import image
from nilearn.image import get_data
from nilearn.plotting import show

from monai.transforms import (
    EnsureChannelFirstd,
    LoadImaged,
    BorderPadd,
    RandAffined,
    Affined,
    EnsureChannelFirstd,
    Compose,
    LoadImaged,
    SaveImaged,
    ScaleIntensityd,
)
from monai.config import print_config
from monai.apps import download_and_extract
from monai.utils import set_determinism, first

import os
import shutil
import glob as glob

print_config()
# Out:
# MONAI version: 1.2.0
# Numpy version: 1.25.0
# Pytorch version: 2.0.1
# MONAI flags: HAS_EXT = False, USE_COMPILED = False, USE_META_DICT = False
# MONAI rev id: c33f1ba588ee00229a309000e888f9817b4f1934
# MONAI __file__: /home/chloe/.conda/envs/torch/lib/python3.11/site-packages/monai/__init__.py
#
# Optional dependencies:
# Pytorch Ignite version: NOT INSTALLED or UNKNOWN VERSION.
# ITK version: 5.3.0
# Nibabel version: 5.1.0
# scikit-image version: 0.20.0
# Pillow version: 9.4.0
# Tensorboard version: NOT INSTALLED or UNKNOWN VERSION.
# gdown version: NOT INSTALLED or UNKNOWN VERSION.
# TorchVision version: 0.15.2
# tqdm version: 4.65.0
# lmdb version: NOT INSTALLED or UNKNOWN VERSION.
# psutil version: 5.9.0
# pandas version: 1.5.3
# einops version: NOT INSTALLED or UNKNOWN VERSION.
# transformers version: NOT INSTALLED or UNKNOWN VERSION.
# mlflow version: NOT INSTALLED or UNKNOWN VERSION.
# pynrrd version: NOT INSTALLED or UNKNOWN VERSION.
#
# For details about installing the optional dependencies, please visit:
#     https://docs.monai.io/en/latest/installation.html#installing-the-recommended-dependencies
#
# Numpy version: 1.25.0
# Pytorch version: 2.0.1
# MONAI flags: HAS_EXT = False, USE_COMPILED = False, USE_META_DICT = False
# MONAI rev id: c33f1ba588ee00229a309000e888f9817b4f1934
# MONAI __file__: /home/chloe/.conda/envs/torch/lib/python3.11/site-packages/monai/__init__.py
#
# Optional dependencies:
# Pytorch Ignite version: NOT INSTALLED or UNKNOWN VERSION.
# ITK version: 5.3.0
# Nibabel version: 5.1.0
# scikit-image version: 0.20.0
# Pillow version: 9.4.0
# Tensorboard version: NOT INSTALLED or UNKNOWN VERSION.
# gdown version: NOT INSTALLED or UNKNOWN VERSION.
# TorchVision version: 0.15.2
# tqdm version: 4.65.0
# lmdb version: NOT INSTALLED or UNKNOWN VERSION.
# psutil version: 5.9.0
# pandas version: 1.5.3
# einops version: NOT INSTALLED or UNKNOWN VERSION.
# transformers version: NOT INSTALLED or UNKNOWN VERSION.
# mlflow version: NOT INSTALLED or UNKNOWN VERSION.
# pynrrd version: NOT INSTALLED or UNKNOWN VERSION.
#
# For details about installing the optional dependencies, please visit:
#     https://docs.monai.io/en/latest/installation.html#installing-the-recommended-dependencies

# %% [markdown]
# Create dataset path and dictionary

# %%
data_dir = "data/"

train_images = sorted(glob.glob(os.path.join(data_dir, "imagesTs", "*.nii.gz")))
train_labels = sorted(glob.glob(os.path.join(data_dir, "labelsTs", "*.nii.gz")))
data_dicts = [{"image": image_name, "label": label_name} for image_name, label_name in zip(train_images, train_labels)]

# %% [markdown]
# Load the iamges to visualize a sampling and get data dimensions

# %%
dimensions = np.zeros([len(data_dicts),3])

for index in range(len(data_dicts)):
    img_path = data_dicts[index]['image']
    lbl_path = data_dicts[index]['label']
    before_rot = image.load_img(img_path)
    before_rot_label = image.load_img(lbl_path)
    dimension = before_rot.shape
    dimensions[index] = dimension

    center = np.divide(dimension,2)
    x_cen = int(np.ceil(center[0]))
    y_cen = int(np.ceil(center[1]))
    z_cen = int(np.ceil(center[2]))

    fig = plt.figure("visualize", (len(data_dicts), 3))
    fig.set_size_inches(10,3)
    plt.subplot(1, 3, 1)
    plt.title(f"Slice through x-center ")
    plt.imshow(get_data(before_rot)[x_cen, :, :])
    plt.subplot(1, 3, 2)
    plt.title(f"Slice through y-center ")
    plt.imshow(get_data(before_rot)[:, y_cen, :])
    plt.subplot(1, 3, 3)
    plt.title(f"Slice through z-center")
    plt.imshow(get_data(before_rot)[:, :, z_cen])
    plt.show()

    fig = plt.figure("labels", (len(data_dicts), 3))
    fig.set_size_inches(10,3)
    plt.subplot(1, 3, 1)
    plt.title(f"Slice through x-center ")
    plt.imshow(get_data(before_rot_label)[x_cen, :, :])
    plt.subplot(1, 3, 2)
    plt.title(f"Slice through y-center ")
    plt.imshow(get_data(before_rot_label)[:, y_cen, :])
    plt.subplot(1, 3, 3)
    plt.title(f"Slice through z-center ")
    plt.imshow(get_data(before_rot_label)[:, :, z_cen])
    plt.show()

# %% [markdown]
# Visualize all the dimensions

# %%
print(dimensions)
# Out:
# [[512. 512. 196.]
#  [512. 512. 229.]
#  [512. 512. 217.]
#  [512. 512. 158.]
#  [512. 512. 197.]
#  [512. 512. 197.]
#  [512. 512. 194.]
#  [512. 512. 205.]
#  [512. 512. 223.]
#  [512. 512. 209.]]

# %% [markdown]
# Set axis of rotation:
# - x = 0
# - y = 1
# - z = 2
#
# Set starting degree, ending degree of rotation, and rotation step.
#
# This code will produce rotations increaseing from starting degree to ending degree with step of chosen degree (ensure this divides evenly).

# %%
axis = 2

start_deg = -10
end_deg = 10
step = 1

if (start_deg - end_deg)%step != 0:
    print("Step does not divide evenly: choose different rotation parameters.")

# %% [markdown]
# Loop over all rotations: Use get_dim_about_z notebook in order to get x,y dimensions using your maximum rotation. For rotations between -30 to 30 degrees, we have a maximum x and y dimension of 572.

# %%
set_dist = 594

deg_array = np.zeros(3)
deg_array[axis] = start_deg - step

#Loop over specified range of degrees
while deg_array[axis] < end_deg:

    #Set degree for iteration
    deg_array[axis] = deg_array[axis] + step
    deg_array_rad = np.deg2rad(deg_array)

    a, b, c = deg_array[0], deg_array[1], deg_array[2]
    a_rad, b_rad, c_rad = deg_array_rad[0], deg_array_rad[1], deg_array_rad[2]

    #Create folders to store rotated images and labels
    image_path = f'results/transformed_results/transformed_images/{a}_{b}_{c}' 
    if not os.path.exists(image_path):
        os.makedirs(image_path)

    label_path = f'results/transformed_results/transformed_labels/{a}_{b}_{c}' 
    if not os.path.exists(label_path):
        os.makedirs(label_path)

    #Produce rotated image with maximum padding for each image
    for index in range(len(data_dicts)):
        data_transform = Compose(
            [
                LoadImaged(keys=["image", "label"]),
                EnsureChannelFirstd(keys=["image", "label"]),
                BorderPadd(keys=["image"],
                        spatial_border = 1, 
                        mode='constant', 
                        lazy=False, 
                        constant_values = -1024),
                BorderPadd(keys=["label"],
                        spatial_border = 1, 
                        mode='constant', 
                        lazy=False,
                        constant_values = 0),
                Affined(keys=["image", "label"],
                    rotate_params = (a_rad, b_rad, c_rad),
                    mode=('bilinear','nearest'),
                    padding_mode=('border'),
                    spatial_size = (set_dist, set_dist, -1),
                    align_corners = True
                ),
                SaveImaged(keys=["image"],
                    output_dir=image_path, 
                    output_postfix =  f"rotated_image_{a}_{b}_{c}_0000",
                    output_ext=".nii.gz",
                    resample = False),
                SaveImaged(keys=["label"],
                    output_dir=label_path, 
                    output_postfix =  f"rotated_label_{a}_{b}_{c}",
                    output_ext=".nii.gz",
                    resample = False),
            ])

        #Runs transformation with specified shape
        transformed_data_dict = data_transform(data_dicts[index])
# Out:
# monai.transforms.io.dictionary LoadImaged.__init__:image_only: Current default value of argument `image_only=False` has been deprecated since version 1.1. It will be changed to `image_only=True` in version 1.3.
# 2023-08-18 10:43:35,145 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-10.0/HN_P002_pre_0000/HN_P002_pre_0000_rotated_image_0.0_0.0_-10.0_0000.nii.gz
# 2023-08-18 10:43:40,687 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-10.0/HN_P002_pre/HN_P002_pre_rotated_label_0.0_0.0_-10.0.nii.gz
# 2023-08-18 10:43:49,967 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-10.0/HN_P003_pre_0000/HN_P003_pre_0000_rotated_image_0.0_0.0_-10.0_0000.nii.gz
# 2023-08-18 10:43:56,467 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-10.0/HN_P003_pre/HN_P003_pre_rotated_label_0.0_0.0_-10.0.nii.gz
# 2023-08-18 10:44:05,565 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-10.0/HN_P005_pre_0000/HN_P005_pre_0000_rotated_image_0.0_0.0_-10.0_0000.nii.gz
# 2023-08-18 10:44:11,459 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-10.0/HN_P005_pre/HN_P005_pre_rotated_label_0.0_0.0_-10.0.nii.gz
# 2023-08-18 10:44:18,901 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-10.0/HN_P007_pre_0000/HN_P007_pre_0000_rotated_image_0.0_0.0_-10.0_0000.nii.gz
# 2023-08-18 10:44:23,519 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-10.0/HN_P007_pre/HN_P007_pre_rotated_label_0.0_0.0_-10.0.nii.gz
# 2023-08-18 10:44:31,476 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-10.0/HN_P008_pre_0000/HN_P008_pre_0000_rotated_image_0.0_0.0_-10.0_0000.nii.gz
# 2023-08-18 10:44:36,827 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-10.0/HN_P008_pre/HN_P008_pre_rotated_label_0.0_0.0_-10.0.nii.gz
# 2023-08-18 10:44:44,982 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-10.0/HN_P009_pre_0000/HN_P009_pre_0000_rotated_image_0.0_0.0_-10.0_0000.nii.gz
# 2023-08-18 10:44:50,481 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-10.0/HN_P009_pre/HN_P009_pre_rotated_label_0.0_0.0_-10.0.nii.gz
# 2023-08-18 10:44:58,889 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-10.0/HN_P010_pre_0000/HN_P010_pre_0000_rotated_image_0.0_0.0_-10.0_0000.nii.gz
# 2023-08-18 10:45:03,980 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-10.0/HN_P010_pre/HN_P010_pre_rotated_label_0.0_0.0_-10.0.nii.gz
# 2023-08-18 10:45:12,746 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-10.0/HN_P011_pre_0000/HN_P011_pre_0000_rotated_image_0.0_0.0_-10.0_0000.nii.gz
# 2023-08-18 10:45:18,643 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-10.0/HN_P011_pre/HN_P011_pre_rotated_label_0.0_0.0_-10.0.nii.gz
# 2023-08-18 10:45:29,809 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-10.0/HN_P014_pre_0000/HN_P014_pre_0000_rotated_image_0.0_0.0_-10.0_0000.nii.gz
# 2023-08-18 10:45:35,811 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-10.0/HN_P014_pre/HN_P014_pre_rotated_label_0.0_0.0_-10.0.nii.gz
# 2023-08-18 10:45:46,738 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-10.0/HN_P016_pre_0000/HN_P016_pre_0000_rotated_image_0.0_0.0_-10.0_0000.nii.gz
# 2023-08-18 10:45:52,161 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-10.0/HN_P016_pre/HN_P016_pre_rotated_label_0.0_0.0_-10.0.nii.gz
# 2023-08-18 10:46:02,486 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-9.0/HN_P002_pre_0000/HN_P002_pre_0000_rotated_image_0.0_0.0_-9.0_0000.nii.gz
# 2023-08-18 10:46:08,126 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-9.0/HN_P002_pre/HN_P002_pre_rotated_label_0.0_0.0_-9.0.nii.gz
# 2023-08-18 10:46:19,979 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-9.0/HN_P003_pre_0000/HN_P003_pre_0000_rotated_image_0.0_0.0_-9.0_0000.nii.gz
# 2023-08-18 10:46:26,619 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-9.0/HN_P003_pre/HN_P003_pre_rotated_label_0.0_0.0_-9.0.nii.gz
# 2023-08-18 10:46:39,887 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-9.0/HN_P005_pre_0000/HN_P005_pre_0000_rotated_image_0.0_0.0_-9.0_0000.nii.gz
# 2023-08-18 10:46:45,927 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-9.0/HN_P005_pre/HN_P005_pre_rotated_label_0.0_0.0_-9.0.nii.gz
# 2023-08-18 10:46:55,967 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-9.0/HN_P007_pre_0000/HN_P007_pre_0000_rotated_image_0.0_0.0_-9.0_0000.nii.gz
# 2023-08-18 10:47:00,622 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-9.0/HN_P007_pre/HN_P007_pre_rotated_label_0.0_0.0_-9.0.nii.gz
# 2023-08-18 10:47:12,197 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-9.0/HN_P008_pre_0000/HN_P008_pre_0000_rotated_image_0.0_0.0_-9.0_0000.nii.gz
# 2023-08-18 10:47:17,552 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-9.0/HN_P008_pre/HN_P008_pre_rotated_label_0.0_0.0_-9.0.nii.gz
# 2023-08-18 10:47:29,586 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-9.0/HN_P009_pre_0000/HN_P009_pre_0000_rotated_image_0.0_0.0_-9.0_0000.nii.gz
# 2023-08-18 10:47:35,074 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-9.0/HN_P009_pre/HN_P009_pre_rotated_label_0.0_0.0_-9.0.nii.gz
# 2023-08-18 10:47:46,952 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-9.0/HN_P010_pre_0000/HN_P010_pre_0000_rotated_image_0.0_0.0_-9.0_0000.nii.gz
# 2023-08-18 10:47:52,035 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-9.0/HN_P010_pre/HN_P010_pre_rotated_label_0.0_0.0_-9.0.nii.gz
# 2023-08-18 10:48:04,639 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-9.0/HN_P011_pre_0000/HN_P011_pre_0000_rotated_image_0.0_0.0_-9.0_0000.nii.gz
# 2023-08-18 10:48:10,530 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-9.0/HN_P011_pre/HN_P011_pre_rotated_label_0.0_0.0_-9.0.nii.gz
# 2023-08-18 10:48:24,158 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-9.0/HN_P014_pre_0000/HN_P014_pre_0000_rotated_image_0.0_0.0_-9.0_0000.nii.gz
# 2023-08-18 10:48:30,145 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-9.0/HN_P014_pre/HN_P014_pre_rotated_label_0.0_0.0_-9.0.nii.gz
# 2023-08-18 10:48:43,224 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-9.0/HN_P016_pre_0000/HN_P016_pre_0000_rotated_image_0.0_0.0_-9.0_0000.nii.gz
# 2023-08-18 10:48:48,661 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-9.0/HN_P016_pre/HN_P016_pre_rotated_label_0.0_0.0_-9.0.nii.gz
# 2023-08-18 10:49:00,833 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-8.0/HN_P002_pre_0000/HN_P002_pre_0000_rotated_image_0.0_0.0_-8.0_0000.nii.gz
# 2023-08-18 10:49:06,503 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-8.0/HN_P002_pre/HN_P002_pre_rotated_label_0.0_0.0_-8.0.nii.gz
# 2023-08-18 10:49:20,552 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-8.0/HN_P003_pre_0000/HN_P003_pre_0000_rotated_image_0.0_0.0_-8.0_0000.nii.gz
# 2023-08-18 10:49:27,167 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-8.0/HN_P003_pre/HN_P003_pre_rotated_label_0.0_0.0_-8.0.nii.gz
# 2023-08-18 10:49:40,647 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-8.0/HN_P005_pre_0000/HN_P005_pre_0000_rotated_image_0.0_0.0_-8.0_0000.nii.gz
# 2023-08-18 10:49:46,692 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-8.0/HN_P005_pre/HN_P005_pre_rotated_label_0.0_0.0_-8.0.nii.gz
# 2023-08-18 10:49:56,762 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-8.0/HN_P007_pre_0000/HN_P007_pre_0000_rotated_image_0.0_0.0_-8.0_0000.nii.gz
# 2023-08-18 10:50:01,407 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-8.0/HN_P007_pre/HN_P007_pre_rotated_label_0.0_0.0_-8.0.nii.gz
# 2023-08-18 10:50:13,094 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-8.0/HN_P008_pre_0000/HN_P008_pre_0000_rotated_image_0.0_0.0_-8.0_0000.nii.gz
# 2023-08-18 10:50:18,430 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-8.0/HN_P008_pre/HN_P008_pre_rotated_label_0.0_0.0_-8.0.nii.gz
# 2023-08-18 10:50:30,474 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-8.0/HN_P009_pre_0000/HN_P009_pre_0000_rotated_image_0.0_0.0_-8.0_0000.nii.gz
# 2023-08-18 10:50:35,963 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-8.0/HN_P009_pre/HN_P009_pre_rotated_label_0.0_0.0_-8.0.nii.gz
# 2023-08-18 10:50:47,868 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-8.0/HN_P010_pre_0000/HN_P010_pre_0000_rotated_image_0.0_0.0_-8.0_0000.nii.gz
# 2023-08-18 10:50:52,885 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-8.0/HN_P010_pre/HN_P010_pre_rotated_label_0.0_0.0_-8.0.nii.gz
# 2023-08-18 10:51:05,334 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-8.0/HN_P011_pre_0000/HN_P011_pre_0000_rotated_image_0.0_0.0_-8.0_0000.nii.gz
# 2023-08-18 10:51:11,218 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-8.0/HN_P011_pre/HN_P011_pre_rotated_label_0.0_0.0_-8.0.nii.gz
# 2023-08-18 10:51:24,826 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-8.0/HN_P014_pre_0000/HN_P014_pre_0000_rotated_image_0.0_0.0_-8.0_0000.nii.gz
# 2023-08-18 10:51:30,707 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-8.0/HN_P014_pre/HN_P014_pre_rotated_label_0.0_0.0_-8.0.nii.gz
# 2023-08-18 10:51:43,752 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-8.0/HN_P016_pre_0000/HN_P016_pre_0000_rotated_image_0.0_0.0_-8.0_0000.nii.gz
# 2023-08-18 10:51:49,128 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-8.0/HN_P016_pre/HN_P016_pre_rotated_label_0.0_0.0_-8.0.nii.gz
# 2023-08-18 10:52:01,304 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-7.0/HN_P002_pre_0000/HN_P002_pre_0000_rotated_image_0.0_0.0_-7.0_0000.nii.gz
# 2023-08-18 10:52:06,922 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-7.0/HN_P002_pre/HN_P002_pre_rotated_label_0.0_0.0_-7.0.nii.gz
# 2023-08-18 10:52:20,827 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-7.0/HN_P003_pre_0000/HN_P003_pre_0000_rotated_image_0.0_0.0_-7.0_0000.nii.gz
# 2023-08-18 10:52:27,451 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-7.0/HN_P003_pre/HN_P003_pre_rotated_label_0.0_0.0_-7.0.nii.gz
# 2023-08-18 10:52:40,950 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-7.0/HN_P005_pre_0000/HN_P005_pre_0000_rotated_image_0.0_0.0_-7.0_0000.nii.gz
# 2023-08-18 10:52:46,911 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-7.0/HN_P005_pre/HN_P005_pre_rotated_label_0.0_0.0_-7.0.nii.gz
# 2023-08-18 10:52:56,870 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-7.0/HN_P007_pre_0000/HN_P007_pre_0000_rotated_image_0.0_0.0_-7.0_0000.nii.gz
# 2023-08-18 10:53:01,504 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-7.0/HN_P007_pre/HN_P007_pre_rotated_label_0.0_0.0_-7.0.nii.gz
# 2023-08-18 10:53:13,170 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-7.0/HN_P008_pre_0000/HN_P008_pre_0000_rotated_image_0.0_0.0_-7.0_0000.nii.gz
# 2023-08-18 10:53:18,509 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-7.0/HN_P008_pre/HN_P008_pre_rotated_label_0.0_0.0_-7.0.nii.gz
# 2023-08-18 10:53:30,532 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-7.0/HN_P009_pre_0000/HN_P009_pre_0000_rotated_image_0.0_0.0_-7.0_0000.nii.gz
# 2023-08-18 10:53:35,965 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-7.0/HN_P009_pre/HN_P009_pre_rotated_label_0.0_0.0_-7.0.nii.gz
# 2023-08-18 10:53:47,752 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-7.0/HN_P010_pre_0000/HN_P010_pre_0000_rotated_image_0.0_0.0_-7.0_0000.nii.gz
# 2023-08-18 10:53:52,816 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-7.0/HN_P010_pre/HN_P010_pre_rotated_label_0.0_0.0_-7.0.nii.gz
# 2023-08-18 10:54:05,301 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-7.0/HN_P011_pre_0000/HN_P011_pre_0000_rotated_image_0.0_0.0_-7.0_0000.nii.gz
# 2023-08-18 10:54:11,188 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-7.0/HN_P011_pre/HN_P011_pre_rotated_label_0.0_0.0_-7.0.nii.gz
# 2023-08-18 10:54:24,726 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-7.0/HN_P014_pre_0000/HN_P014_pre_0000_rotated_image_0.0_0.0_-7.0_0000.nii.gz
# 2023-08-18 10:54:30,644 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-7.0/HN_P014_pre/HN_P014_pre_rotated_label_0.0_0.0_-7.0.nii.gz
# 2023-08-18 10:54:43,589 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-7.0/HN_P016_pre_0000/HN_P016_pre_0000_rotated_image_0.0_0.0_-7.0_0000.nii.gz
# 2023-08-18 10:54:48,988 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-7.0/HN_P016_pre/HN_P016_pre_rotated_label_0.0_0.0_-7.0.nii.gz
# 2023-08-18 10:55:01,091 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-6.0/HN_P002_pre_0000/HN_P002_pre_0000_rotated_image_0.0_0.0_-6.0_0000.nii.gz
# 2023-08-18 10:55:06,742 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-6.0/HN_P002_pre/HN_P002_pre_rotated_label_0.0_0.0_-6.0.nii.gz
# 2023-08-18 10:55:20,678 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-6.0/HN_P003_pre_0000/HN_P003_pre_0000_rotated_image_0.0_0.0_-6.0_0000.nii.gz
# 2023-08-18 10:55:27,305 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-6.0/HN_P003_pre/HN_P003_pre_rotated_label_0.0_0.0_-6.0.nii.gz
# 2023-08-18 10:55:41,477 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-6.0/HN_P005_pre_0000/HN_P005_pre_0000_rotated_image_0.0_0.0_-6.0_0000.nii.gz
# 2023-08-18 10:55:47,510 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-6.0/HN_P005_pre/HN_P005_pre_rotated_label_0.0_0.0_-6.0.nii.gz
# 2023-08-18 10:55:59,038 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-6.0/HN_P007_pre_0000/HN_P007_pre_0000_rotated_image_0.0_0.0_-6.0_0000.nii.gz
# 2023-08-18 10:56:03,665 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-6.0/HN_P007_pre/HN_P007_pre_rotated_label_0.0_0.0_-6.0.nii.gz
# 2023-08-18 10:56:17,258 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-6.0/HN_P008_pre_0000/HN_P008_pre_0000_rotated_image_0.0_0.0_-6.0_0000.nii.gz
# 2023-08-18 10:56:22,608 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-6.0/HN_P008_pre/HN_P008_pre_rotated_label_0.0_0.0_-6.0.nii.gz
# 2023-08-18 10:56:36,750 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-6.0/HN_P009_pre_0000/HN_P009_pre_0000_rotated_image_0.0_0.0_-6.0_0000.nii.gz
# 2023-08-18 10:56:42,225 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-6.0/HN_P009_pre/HN_P009_pre_rotated_label_0.0_0.0_-6.0.nii.gz
# 2023-08-18 10:56:56,175 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-6.0/HN_P010_pre_0000/HN_P010_pre_0000_rotated_image_0.0_0.0_-6.0_0000.nii.gz
# 2023-08-18 10:57:01,229 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-6.0/HN_P010_pre/HN_P010_pre_rotated_label_0.0_0.0_-6.0.nii.gz
# 2023-08-18 10:57:15,985 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-6.0/HN_P011_pre_0000/HN_P011_pre_0000_rotated_image_0.0_0.0_-6.0_0000.nii.gz
# 2023-08-18 10:57:21,841 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-6.0/HN_P011_pre/HN_P011_pre_rotated_label_0.0_0.0_-6.0.nii.gz
# 2023-08-18 10:57:37,572 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-6.0/HN_P014_pre_0000/HN_P014_pre_0000_rotated_image_0.0_0.0_-6.0_0000.nii.gz
# 2023-08-18 10:57:43,534 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-6.0/HN_P014_pre/HN_P014_pre_rotated_label_0.0_0.0_-6.0.nii.gz
# 2023-08-18 10:57:59,386 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-6.0/HN_P016_pre_0000/HN_P016_pre_0000_rotated_image_0.0_0.0_-6.0_0000.nii.gz
# 2023-08-18 10:58:04,810 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-6.0/HN_P016_pre/HN_P016_pre_rotated_label_0.0_0.0_-6.0.nii.gz
# 2023-08-18 10:58:20,126 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-5.0/HN_P002_pre_0000/HN_P002_pre_0000_rotated_image_0.0_0.0_-5.0_0000.nii.gz
# 2023-08-18 10:58:25,774 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-5.0/HN_P002_pre/HN_P002_pre_rotated_label_0.0_0.0_-5.0.nii.gz
# 2023-08-18 10:58:43,512 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-5.0/HN_P003_pre_0000/HN_P003_pre_0000_rotated_image_0.0_0.0_-5.0_0000.nii.gz
# 2023-08-18 10:58:50,126 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-5.0/HN_P003_pre/HN_P003_pre_rotated_label_0.0_0.0_-5.0.nii.gz
# 2023-08-18 10:59:07,125 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-5.0/HN_P005_pre_0000/HN_P005_pre_0000_rotated_image_0.0_0.0_-5.0_0000.nii.gz
# 2023-08-18 10:59:13,146 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-5.0/HN_P005_pre/HN_P005_pre_rotated_label_0.0_0.0_-5.0.nii.gz
# 2023-08-18 10:59:25,713 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-5.0/HN_P007_pre_0000/HN_P007_pre_0000_rotated_image_0.0_0.0_-5.0_0000.nii.gz
# 2023-08-18 10:59:30,350 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-5.0/HN_P007_pre/HN_P007_pre_rotated_label_0.0_0.0_-5.0.nii.gz
# 2023-08-18 10:59:45,007 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-5.0/HN_P008_pre_0000/HN_P008_pre_0000_rotated_image_0.0_0.0_-5.0_0000.nii.gz
# 2023-08-18 10:59:50,347 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-5.0/HN_P008_pre/HN_P008_pre_rotated_label_0.0_0.0_-5.0.nii.gz
# 2023-08-18 11:00:05,751 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-5.0/HN_P009_pre_0000/HN_P009_pre_0000_rotated_image_0.0_0.0_-5.0_0000.nii.gz
# 2023-08-18 11:00:11,201 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-5.0/HN_P009_pre/HN_P009_pre_rotated_label_0.0_0.0_-5.0.nii.gz
# 2023-08-18 11:00:26,305 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-5.0/HN_P010_pre_0000/HN_P010_pre_0000_rotated_image_0.0_0.0_-5.0_0000.nii.gz
# 2023-08-18 11:00:31,336 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-5.0/HN_P010_pre/HN_P010_pre_rotated_label_0.0_0.0_-5.0.nii.gz
# 2023-08-18 11:00:47,201 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-5.0/HN_P011_pre_0000/HN_P011_pre_0000_rotated_image_0.0_0.0_-5.0_0000.nii.gz
# 2023-08-18 11:00:53,042 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-5.0/HN_P011_pre/HN_P011_pre_rotated_label_0.0_0.0_-5.0.nii.gz
# 2023-08-18 11:01:10,152 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-5.0/HN_P014_pre_0000/HN_P014_pre_0000_rotated_image_0.0_0.0_-5.0_0000.nii.gz
# 2023-08-18 11:01:16,100 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-5.0/HN_P014_pre/HN_P014_pre_rotated_label_0.0_0.0_-5.0.nii.gz
# 2023-08-18 11:01:32,596 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-5.0/HN_P016_pre_0000/HN_P016_pre_0000_rotated_image_0.0_0.0_-5.0_0000.nii.gz
# 2023-08-18 11:01:37,998 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-5.0/HN_P016_pre/HN_P016_pre_rotated_label_0.0_0.0_-5.0.nii.gz
# 2023-08-18 11:01:53,252 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-4.0/HN_P002_pre_0000/HN_P002_pre_0000_rotated_image_0.0_0.0_-4.0_0000.nii.gz
# 2023-08-18 11:01:58,873 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-4.0/HN_P002_pre/HN_P002_pre_rotated_label_0.0_0.0_-4.0.nii.gz
# 2023-08-18 11:02:16,583 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-4.0/HN_P003_pre_0000/HN_P003_pre_0000_rotated_image_0.0_0.0_-4.0_0000.nii.gz
# 2023-08-18 11:02:23,174 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-4.0/HN_P003_pre/HN_P003_pre_rotated_label_0.0_0.0_-4.0.nii.gz
# 2023-08-18 11:02:40,163 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-4.0/HN_P005_pre_0000/HN_P005_pre_0000_rotated_image_0.0_0.0_-4.0_0000.nii.gz
# 2023-08-18 11:02:46,177 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-4.0/HN_P005_pre/HN_P005_pre_rotated_label_0.0_0.0_-4.0.nii.gz
# 2023-08-18 11:02:58,744 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-4.0/HN_P007_pre_0000/HN_P007_pre_0000_rotated_image_0.0_0.0_-4.0_0000.nii.gz
# 2023-08-18 11:03:03,370 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-4.0/HN_P007_pre/HN_P007_pre_rotated_label_0.0_0.0_-4.0.nii.gz
# 2023-08-18 11:03:18,205 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-4.0/HN_P008_pre_0000/HN_P008_pre_0000_rotated_image_0.0_0.0_-4.0_0000.nii.gz
# 2023-08-18 11:03:23,540 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-4.0/HN_P008_pre/HN_P008_pre_rotated_label_0.0_0.0_-4.0.nii.gz
# 2023-08-18 11:03:38,813 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-4.0/HN_P009_pre_0000/HN_P009_pre_0000_rotated_image_0.0_0.0_-4.0_0000.nii.gz
# 2023-08-18 11:03:44,261 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-4.0/HN_P009_pre/HN_P009_pre_rotated_label_0.0_0.0_-4.0.nii.gz
# 2023-08-18 11:03:59,287 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-4.0/HN_P010_pre_0000/HN_P010_pre_0000_rotated_image_0.0_0.0_-4.0_0000.nii.gz
# 2023-08-18 11:04:04,331 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-4.0/HN_P010_pre/HN_P010_pre_rotated_label_0.0_0.0_-4.0.nii.gz
# 2023-08-18 11:04:20,235 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-4.0/HN_P011_pre_0000/HN_P011_pre_0000_rotated_image_0.0_0.0_-4.0_0000.nii.gz
# 2023-08-18 11:04:26,090 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-4.0/HN_P011_pre/HN_P011_pre_rotated_label_0.0_0.0_-4.0.nii.gz
# 2023-08-18 11:04:42,982 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-4.0/HN_P014_pre_0000/HN_P014_pre_0000_rotated_image_0.0_0.0_-4.0_0000.nii.gz
# 2023-08-18 11:04:48,931 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-4.0/HN_P014_pre/HN_P014_pre_rotated_label_0.0_0.0_-4.0.nii.gz
# 2023-08-18 11:05:05,112 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-4.0/HN_P016_pre_0000/HN_P016_pre_0000_rotated_image_0.0_0.0_-4.0_0000.nii.gz
# 2023-08-18 11:05:10,518 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-4.0/HN_P016_pre/HN_P016_pre_rotated_label_0.0_0.0_-4.0.nii.gz
# 2023-08-18 11:05:25,853 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-3.0/HN_P002_pre_0000/HN_P002_pre_0000_rotated_image_0.0_0.0_-3.0_0000.nii.gz
# 2023-08-18 11:05:31,484 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-3.0/HN_P002_pre/HN_P002_pre_rotated_label_0.0_0.0_-3.0.nii.gz
# 2023-08-18 11:05:49,060 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-3.0/HN_P003_pre_0000/HN_P003_pre_0000_rotated_image_0.0_0.0_-3.0_0000.nii.gz
# 2023-08-18 11:05:55,592 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-3.0/HN_P003_pre/HN_P003_pre_rotated_label_0.0_0.0_-3.0.nii.gz
# 2023-08-18 11:06:12,502 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-3.0/HN_P005_pre_0000/HN_P005_pre_0000_rotated_image_0.0_0.0_-3.0_0000.nii.gz
# 2023-08-18 11:06:18,477 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-3.0/HN_P005_pre/HN_P005_pre_rotated_label_0.0_0.0_-3.0.nii.gz
# 2023-08-18 11:06:31,015 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-3.0/HN_P007_pre_0000/HN_P007_pre_0000_rotated_image_0.0_0.0_-3.0_0000.nii.gz
# 2023-08-18 11:06:35,640 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-3.0/HN_P007_pre/HN_P007_pre_rotated_label_0.0_0.0_-3.0.nii.gz
# 2023-08-18 11:06:50,314 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-3.0/HN_P008_pre_0000/HN_P008_pre_0000_rotated_image_0.0_0.0_-3.0_0000.nii.gz
# 2023-08-18 11:06:55,584 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-3.0/HN_P008_pre/HN_P008_pre_rotated_label_0.0_0.0_-3.0.nii.gz
# 2023-08-18 11:07:10,796 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-3.0/HN_P009_pre_0000/HN_P009_pre_0000_rotated_image_0.0_0.0_-3.0_0000.nii.gz
# 2023-08-18 11:07:16,173 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-3.0/HN_P009_pre/HN_P009_pre_rotated_label_0.0_0.0_-3.0.nii.gz
# 2023-08-18 11:07:31,308 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-3.0/HN_P010_pre_0000/HN_P010_pre_0000_rotated_image_0.0_0.0_-3.0_0000.nii.gz
# 2023-08-18 11:07:36,312 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-3.0/HN_P010_pre/HN_P010_pre_rotated_label_0.0_0.0_-3.0.nii.gz
# 2023-08-18 11:07:52,173 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-3.0/HN_P011_pre_0000/HN_P011_pre_0000_rotated_image_0.0_0.0_-3.0_0000.nii.gz
# 2023-08-18 11:07:57,995 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-3.0/HN_P011_pre/HN_P011_pre_rotated_label_0.0_0.0_-3.0.nii.gz
# 2023-08-18 11:08:15,181 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-3.0/HN_P014_pre_0000/HN_P014_pre_0000_rotated_image_0.0_0.0_-3.0_0000.nii.gz
# 2023-08-18 11:08:21,099 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-3.0/HN_P014_pre/HN_P014_pre_rotated_label_0.0_0.0_-3.0.nii.gz
# 2023-08-18 11:08:37,404 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-3.0/HN_P016_pre_0000/HN_P016_pre_0000_rotated_image_0.0_0.0_-3.0_0000.nii.gz
# 2023-08-18 11:08:42,763 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-3.0/HN_P016_pre/HN_P016_pre_rotated_label_0.0_0.0_-3.0.nii.gz
# 2023-08-18 11:08:58,110 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-2.0/HN_P002_pre_0000/HN_P002_pre_0000_rotated_image_0.0_0.0_-2.0_0000.nii.gz
# 2023-08-18 11:09:03,704 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-2.0/HN_P002_pre/HN_P002_pre_rotated_label_0.0_0.0_-2.0.nii.gz
# 2023-08-18 11:09:21,367 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-2.0/HN_P003_pre_0000/HN_P003_pre_0000_rotated_image_0.0_0.0_-2.0_0000.nii.gz
# 2023-08-18 11:09:27,958 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-2.0/HN_P003_pre/HN_P003_pre_rotated_label_0.0_0.0_-2.0.nii.gz
# 2023-08-18 11:09:44,942 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-2.0/HN_P005_pre_0000/HN_P005_pre_0000_rotated_image_0.0_0.0_-2.0_0000.nii.gz
# 2023-08-18 11:09:50,946 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-2.0/HN_P005_pre/HN_P005_pre_rotated_label_0.0_0.0_-2.0.nii.gz
# 2023-08-18 11:10:03,441 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-2.0/HN_P007_pre_0000/HN_P007_pre_0000_rotated_image_0.0_0.0_-2.0_0000.nii.gz
# 2023-08-18 11:10:08,034 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-2.0/HN_P007_pre/HN_P007_pre_rotated_label_0.0_0.0_-2.0.nii.gz
# 2023-08-18 11:10:22,669 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-2.0/HN_P008_pre_0000/HN_P008_pre_0000_rotated_image_0.0_0.0_-2.0_0000.nii.gz
# 2023-08-18 11:10:27,987 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-2.0/HN_P008_pre/HN_P008_pre_rotated_label_0.0_0.0_-2.0.nii.gz
# 2023-08-18 11:10:43,192 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-2.0/HN_P009_pre_0000/HN_P009_pre_0000_rotated_image_0.0_0.0_-2.0_0000.nii.gz
# 2023-08-18 11:10:48,619 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-2.0/HN_P009_pre/HN_P009_pre_rotated_label_0.0_0.0_-2.0.nii.gz
# 2023-08-18 11:11:03,640 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-2.0/HN_P010_pre_0000/HN_P010_pre_0000_rotated_image_0.0_0.0_-2.0_0000.nii.gz
# 2023-08-18 11:11:08,679 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-2.0/HN_P010_pre/HN_P010_pre_rotated_label_0.0_0.0_-2.0.nii.gz
# 2023-08-18 11:11:24,624 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-2.0/HN_P011_pre_0000/HN_P011_pre_0000_rotated_image_0.0_0.0_-2.0_0000.nii.gz
# 2023-08-18 11:11:30,470 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-2.0/HN_P011_pre/HN_P011_pre_rotated_label_0.0_0.0_-2.0.nii.gz
# 2023-08-18 11:11:47,590 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-2.0/HN_P014_pre_0000/HN_P014_pre_0000_rotated_image_0.0_0.0_-2.0_0000.nii.gz
# 2023-08-18 11:11:53,521 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-2.0/HN_P014_pre/HN_P014_pre_rotated_label_0.0_0.0_-2.0.nii.gz
# 2023-08-18 11:12:09,782 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-2.0/HN_P016_pre_0000/HN_P016_pre_0000_rotated_image_0.0_0.0_-2.0_0000.nii.gz
# 2023-08-18 11:12:15,168 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-2.0/HN_P016_pre/HN_P016_pre_rotated_label_0.0_0.0_-2.0.nii.gz
# 2023-08-18 11:12:30,480 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-1.0/HN_P002_pre_0000/HN_P002_pre_0000_rotated_image_0.0_0.0_-1.0_0000.nii.gz
# 2023-08-18 11:12:36,087 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-1.0/HN_P002_pre/HN_P002_pre_rotated_label_0.0_0.0_-1.0.nii.gz
# 2023-08-18 11:12:53,733 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-1.0/HN_P003_pre_0000/HN_P003_pre_0000_rotated_image_0.0_0.0_-1.0_0000.nii.gz
# 2023-08-18 11:13:00,315 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-1.0/HN_P003_pre/HN_P003_pre_rotated_label_0.0_0.0_-1.0.nii.gz
# 2023-08-18 11:13:17,292 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-1.0/HN_P005_pre_0000/HN_P005_pre_0000_rotated_image_0.0_0.0_-1.0_0000.nii.gz
# 2023-08-18 11:13:23,277 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-1.0/HN_P005_pre/HN_P005_pre_rotated_label_0.0_0.0_-1.0.nii.gz
# 2023-08-18 11:13:35,837 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-1.0/HN_P007_pre_0000/HN_P007_pre_0000_rotated_image_0.0_0.0_-1.0_0000.nii.gz
# 2023-08-18 11:13:40,440 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-1.0/HN_P007_pre/HN_P007_pre_rotated_label_0.0_0.0_-1.0.nii.gz
# 2023-08-18 11:13:55,263 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-1.0/HN_P008_pre_0000/HN_P008_pre_0000_rotated_image_0.0_0.0_-1.0_0000.nii.gz
# 2023-08-18 11:14:00,574 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-1.0/HN_P008_pre/HN_P008_pre_rotated_label_0.0_0.0_-1.0.nii.gz
# 2023-08-18 11:14:19,397 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-1.0/HN_P009_pre_0000/HN_P009_pre_0000_rotated_image_0.0_0.0_-1.0_0000.nii.gz
# 2023-08-18 11:14:24,813 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-1.0/HN_P009_pre/HN_P009_pre_rotated_label_0.0_0.0_-1.0.nii.gz
# 2023-08-18 11:14:43,398 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-1.0/HN_P010_pre_0000/HN_P010_pre_0000_rotated_image_0.0_0.0_-1.0_0000.nii.gz
# 2023-08-18 11:14:48,395 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-1.0/HN_P010_pre/HN_P010_pre_rotated_label_0.0_0.0_-1.0.nii.gz
# 2023-08-18 11:15:07,806 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-1.0/HN_P011_pre_0000/HN_P011_pre_0000_rotated_image_0.0_0.0_-1.0_0000.nii.gz
# 2023-08-18 11:15:13,644 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-1.0/HN_P011_pre/HN_P011_pre_rotated_label_0.0_0.0_-1.0.nii.gz
# 2023-08-18 11:15:34,893 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-1.0/HN_P014_pre_0000/HN_P014_pre_0000_rotated_image_0.0_0.0_-1.0_0000.nii.gz
# 2023-08-18 11:15:40,804 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-1.0/HN_P014_pre/HN_P014_pre_rotated_label_0.0_0.0_-1.0.nii.gz
# 2023-08-18 11:16:00,893 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_-1.0/HN_P016_pre_0000/HN_P016_pre_0000_rotated_image_0.0_0.0_-1.0_0000.nii.gz
# 2023-08-18 11:16:06,232 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_-1.0/HN_P016_pre/HN_P016_pre_rotated_label_0.0_0.0_-1.0.nii.gz
# 2023-08-18 11:16:25,086 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_0.0/HN_P002_pre_0000/HN_P002_pre_0000_rotated_image_0.0_0.0_0.0_0000.nii.gz
# 2023-08-18 11:16:30,712 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_0.0/HN_P002_pre/HN_P002_pre_rotated_label_0.0_0.0_0.0.nii.gz
# 2023-08-18 11:16:52,580 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_0.0/HN_P003_pre_0000/HN_P003_pre_0000_rotated_image_0.0_0.0_0.0_0000.nii.gz
# 2023-08-18 11:16:59,179 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_0.0/HN_P003_pre/HN_P003_pre_rotated_label_0.0_0.0_0.0.nii.gz
# 2023-08-18 11:17:20,154 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_0.0/HN_P005_pre_0000/HN_P005_pre_0000_rotated_image_0.0_0.0_0.0_0000.nii.gz
# 2023-08-18 11:17:26,143 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_0.0/HN_P005_pre/HN_P005_pre_rotated_label_0.0_0.0_0.0.nii.gz
# 2023-08-18 11:17:41,541 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_0.0/HN_P007_pre_0000/HN_P007_pre_0000_rotated_image_0.0_0.0_0.0_0000.nii.gz
# 2023-08-18 11:17:46,137 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_0.0/HN_P007_pre/HN_P007_pre_rotated_label_0.0_0.0_0.0.nii.gz
# 2023-08-18 11:18:04,391 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_0.0/HN_P008_pre_0000/HN_P008_pre_0000_rotated_image_0.0_0.0_0.0_0000.nii.gz
# 2023-08-18 11:18:09,724 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_0.0/HN_P008_pre/HN_P008_pre_rotated_label_0.0_0.0_0.0.nii.gz
# 2023-08-18 11:18:28,674 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_0.0/HN_P009_pre_0000/HN_P009_pre_0000_rotated_image_0.0_0.0_0.0_0000.nii.gz
# 2023-08-18 11:18:34,117 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_0.0/HN_P009_pre/HN_P009_pre_rotated_label_0.0_0.0_0.0.nii.gz
# ...
# 2023-08-18 11:48:38,159 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_7.0/HN_P008_pre/HN_P008_pre_rotated_label_0.0_0.0_7.0.nii.gz
# 2023-08-18 11:48:57,048 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_7.0/HN_P009_pre_0000/HN_P009_pre_0000_rotated_image_0.0_0.0_7.0_0000.nii.gz
# 2023-08-18 11:49:02,627 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_7.0/HN_P009_pre/HN_P009_pre_rotated_label_0.0_0.0_7.0.nii.gz
# 2023-08-18 11:49:24,136 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_7.0/HN_P010_pre_0000/HN_P010_pre_0000_rotated_image_0.0_0.0_7.0_0000.nii.gz
# 2023-08-18 11:49:29,191 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_7.0/HN_P010_pre/HN_P010_pre_rotated_label_0.0_0.0_7.0.nii.gz
# 2023-08-18 11:49:52,060 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_7.0/HN_P011_pre_0000/HN_P011_pre_0000_rotated_image_0.0_0.0_7.0_0000.nii.gz
# 2023-08-18 11:49:57,918 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_7.0/HN_P011_pre/HN_P011_pre_rotated_label_0.0_0.0_7.0.nii.gz
# 2023-08-18 11:50:22,536 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_7.0/HN_P014_pre_0000/HN_P014_pre_0000_rotated_image_0.0_0.0_7.0_0000.nii.gz
# 2023-08-18 11:50:28,432 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_7.0/HN_P014_pre/HN_P014_pre_rotated_label_0.0_0.0_7.0.nii.gz
# 2023-08-18 11:50:51,876 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_7.0/HN_P016_pre_0000/HN_P016_pre_0000_rotated_image_0.0_0.0_7.0_0000.nii.gz
# 2023-08-18 11:50:57,306 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_7.0/HN_P016_pre/HN_P016_pre_rotated_label_0.0_0.0_7.0.nii.gz
# 2023-08-18 11:51:19,421 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_8.0/HN_P002_pre_0000/HN_P002_pre_0000_rotated_image_0.0_0.0_8.0_0000.nii.gz
# 2023-08-18 11:51:25,059 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_8.0/HN_P002_pre/HN_P002_pre_rotated_label_0.0_0.0_8.0.nii.gz
# 2023-08-18 11:51:50,591 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_8.0/HN_P003_pre_0000/HN_P003_pre_0000_rotated_image_0.0_0.0_8.0_0000.nii.gz
# 2023-08-18 11:51:57,224 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_8.0/HN_P003_pre/HN_P003_pre_rotated_label_0.0_0.0_8.0.nii.gz
# 2023-08-18 11:52:21,659 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_8.0/HN_P005_pre_0000/HN_P005_pre_0000_rotated_image_0.0_0.0_8.0_0000.nii.gz
# 2023-08-18 11:52:27,698 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_8.0/HN_P005_pre/HN_P005_pre_rotated_label_0.0_0.0_8.0.nii.gz
# 2023-08-18 11:52:45,276 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_8.0/HN_P007_pre_0000/HN_P007_pre_0000_rotated_image_0.0_0.0_8.0_0000.nii.gz
# 2023-08-18 11:52:49,933 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_8.0/HN_P007_pre/HN_P007_pre_rotated_label_0.0_0.0_8.0.nii.gz
# 2023-08-18 11:53:11,395 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_8.0/HN_P008_pre_0000/HN_P008_pre_0000_rotated_image_0.0_0.0_8.0_0000.nii.gz
# 2023-08-18 11:53:16,751 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_8.0/HN_P008_pre/HN_P008_pre_rotated_label_0.0_0.0_8.0.nii.gz
# 2023-08-18 11:53:38,752 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_8.0/HN_P009_pre_0000/HN_P009_pre_0000_rotated_image_0.0_0.0_8.0_0000.nii.gz
# 2023-08-18 11:53:44,226 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_8.0/HN_P009_pre/HN_P009_pre_rotated_label_0.0_0.0_8.0.nii.gz
# 2023-08-18 11:54:01,600 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_8.0/HN_P010_pre_0000/HN_P010_pre_0000_rotated_image_0.0_0.0_8.0_0000.nii.gz
# 2023-08-18 11:54:06,715 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_8.0/HN_P010_pre/HN_P010_pre_rotated_label_0.0_0.0_8.0.nii.gz
# 2023-08-18 11:54:29,553 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_8.0/HN_P011_pre_0000/HN_P011_pre_0000_rotated_image_0.0_0.0_8.0_0000.nii.gz
# 2023-08-18 11:54:35,422 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_8.0/HN_P011_pre/HN_P011_pre_rotated_label_0.0_0.0_8.0.nii.gz
# 2023-08-18 11:54:44,072 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_8.0/HN_P014_pre_0000/HN_P014_pre_0000_rotated_image_0.0_0.0_8.0_0000.nii.gz
# 2023-08-18 11:54:50,081 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_8.0/HN_P014_pre/HN_P014_pre_rotated_label_0.0_0.0_8.0.nii.gz
# 2023-08-18 11:54:58,333 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_8.0/HN_P016_pre_0000/HN_P016_pre_0000_rotated_image_0.0_0.0_8.0_0000.nii.gz
# 2023-08-18 11:55:03,756 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_8.0/HN_P016_pre/HN_P016_pre_rotated_label_0.0_0.0_8.0.nii.gz
# 2023-08-18 11:55:11,676 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_9.0/HN_P002_pre_0000/HN_P002_pre_0000_rotated_image_0.0_0.0_9.0_0000.nii.gz
# 2023-08-18 11:55:17,366 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_9.0/HN_P002_pre/HN_P002_pre_rotated_label_0.0_0.0_9.0.nii.gz
# 2023-08-18 11:55:26,338 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_9.0/HN_P003_pre_0000/HN_P003_pre_0000_rotated_image_0.0_0.0_9.0_0000.nii.gz
# 2023-08-18 11:55:32,968 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_9.0/HN_P003_pre/HN_P003_pre_rotated_label_0.0_0.0_9.0.nii.gz
# 2023-08-18 11:55:41,687 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_9.0/HN_P005_pre_0000/HN_P005_pre_0000_rotated_image_0.0_0.0_9.0_0000.nii.gz
# 2023-08-18 11:55:47,748 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_9.0/HN_P005_pre/HN_P005_pre_rotated_label_0.0_0.0_9.0.nii.gz
# 2023-08-18 11:55:54,676 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_9.0/HN_P007_pre_0000/HN_P007_pre_0000_rotated_image_0.0_0.0_9.0_0000.nii.gz
# 2023-08-18 11:55:59,435 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_9.0/HN_P007_pre/HN_P007_pre_rotated_label_0.0_0.0_9.0.nii.gz
# 2023-08-18 11:56:06,891 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_9.0/HN_P008_pre_0000/HN_P008_pre_0000_rotated_image_0.0_0.0_9.0_0000.nii.gz
# 2023-08-18 11:56:12,294 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_9.0/HN_P008_pre/HN_P008_pre_rotated_label_0.0_0.0_9.0.nii.gz
# 2023-08-18 11:56:19,690 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_9.0/HN_P009_pre_0000/HN_P009_pre_0000_rotated_image_0.0_0.0_9.0_0000.nii.gz
# 2023-08-18 11:56:25,212 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_9.0/HN_P009_pre/HN_P009_pre_rotated_label_0.0_0.0_9.0.nii.gz
# 2023-08-18 11:56:42,028 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_9.0/HN_P010_pre_0000/HN_P010_pre_0000_rotated_image_0.0_0.0_9.0_0000.nii.gz
# 2023-08-18 11:56:47,150 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_9.0/HN_P010_pre/HN_P010_pre_rotated_label_0.0_0.0_9.0.nii.gz
# 2023-08-18 11:56:56,792 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_9.0/HN_P011_pre_0000/HN_P011_pre_0000_rotated_image_0.0_0.0_9.0_0000.nii.gz
# 2023-08-18 11:57:02,363 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_9.0/HN_P011_pre/HN_P011_pre_rotated_label_0.0_0.0_9.0.nii.gz
# 2023-08-18 11:57:10,772 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_9.0/HN_P014_pre_0000/HN_P014_pre_0000_rotated_image_0.0_0.0_9.0_0000.nii.gz
# 2023-08-18 11:57:16,452 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_9.0/HN_P014_pre/HN_P014_pre_rotated_label_0.0_0.0_9.0.nii.gz
# 2023-08-18 11:57:24,607 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_9.0/HN_P016_pre_0000/HN_P016_pre_0000_rotated_image_0.0_0.0_9.0_0000.nii.gz
# 2023-08-18 11:57:29,789 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_9.0/HN_P016_pre/HN_P016_pre_rotated_label_0.0_0.0_9.0.nii.gz
# 2023-08-18 11:57:37,469 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_10.0/HN_P002_pre_0000/HN_P002_pre_0000_rotated_image_0.0_0.0_10.0_0000.nii.gz
# 2023-08-18 11:57:42,890 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_10.0/HN_P002_pre/HN_P002_pre_rotated_label_0.0_0.0_10.0.nii.gz
# 2023-08-18 11:57:51,569 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_10.0/HN_P003_pre_0000/HN_P003_pre_0000_rotated_image_0.0_0.0_10.0_0000.nii.gz
# 2023-08-18 11:57:57,894 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_10.0/HN_P003_pre/HN_P003_pre_rotated_label_0.0_0.0_10.0.nii.gz
# 2023-08-18 11:58:06,314 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_10.0/HN_P005_pre_0000/HN_P005_pre_0000_rotated_image_0.0_0.0_10.0_0000.nii.gz
# 2023-08-18 11:58:12,065 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_10.0/HN_P005_pre/HN_P005_pre_rotated_label_0.0_0.0_10.0.nii.gz
# 2023-08-18 11:58:18,764 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_10.0/HN_P007_pre_0000/HN_P007_pre_0000_rotated_image_0.0_0.0_10.0_0000.nii.gz
# 2023-08-18 11:58:23,180 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_10.0/HN_P007_pre/HN_P007_pre_rotated_label_0.0_0.0_10.0.nii.gz
# 2023-08-18 11:58:30,566 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_10.0/HN_P008_pre_0000/HN_P008_pre_0000_rotated_image_0.0_0.0_10.0_0000.nii.gz
# 2023-08-18 11:58:35,682 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_10.0/HN_P008_pre/HN_P008_pre_rotated_label_0.0_0.0_10.0.nii.gz
# 2023-08-18 11:58:46,806 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_10.0/HN_P009_pre_0000/HN_P009_pre_0000_rotated_image_0.0_0.0_10.0_0000.nii.gz
# 2023-08-18 11:58:52,046 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_10.0/HN_P009_pre/HN_P009_pre_rotated_label_0.0_0.0_10.0.nii.gz
# 2023-08-18 11:59:05,967 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_10.0/HN_P010_pre_0000/HN_P010_pre_0000_rotated_image_0.0_0.0_10.0_0000.nii.gz
# 2023-08-18 11:59:10,807 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_10.0/HN_P010_pre/HN_P010_pre_rotated_label_0.0_0.0_10.0.nii.gz
# 2023-08-18 11:59:22,968 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_10.0/HN_P011_pre_0000/HN_P011_pre_0000_rotated_image_0.0_0.0_10.0_0000.nii.gz
# 2023-08-18 11:59:28,552 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_10.0/HN_P011_pre/HN_P011_pre_rotated_label_0.0_0.0_10.0.nii.gz
# 2023-08-18 11:59:41,225 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_10.0/HN_P014_pre_0000/HN_P014_pre_0000_rotated_image_0.0_0.0_10.0_0000.nii.gz
# 2023-08-18 11:59:46,962 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_10.0/HN_P014_pre/HN_P014_pre_rotated_label_0.0_0.0_10.0.nii.gz
# 2023-08-18 11:59:59,161 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_images/0.0_0.0_10.0/HN_P016_pre_0000/HN_P016_pre_0000_rotated_image_0.0_0.0_10.0_0000.nii.gz
# 2023-08-18 12:00:04,366 INFO image_writer.py:197 - writing: /home/chloe/research/code/inference_06/results/transformed_results/transformed_labels/0.0_0.0_10.0/HN_P016_pre/HN_P016_pre_rotated_label_0.0_0.0_10.0.nii.gz

# %% [markdown]
# Copy rotated images into nnUnet folder for testing

# %%
# Define the path to where you store transformed data and where to store nnUnet data
transform_image_dir = 'results/transformed_results/transformed_images'
nnUnet_data_path = '/home/chloe/nnUNet_raw_data_base/nnUNet_raw_data/Task603_SettingUp/imagesTs' #Change this to where you store nnUnet data

# Code to move transformed data from subfolders to single folder
rot_list = os.listdir(transform_image_dir) 

for rot in rot_list:
    rot_path = os.path.join(transform_image_dir, rot)
    patient_names = os.listdir(rot_path)
    for patient in patient_names:
        patient_path = os.path.join(rot_path, patient)
        image_names = os.listdir(patient_path)
        for image in image_names:
            image_path = os.path.join(patient_path, image)
            shutil.copy(image_path, nnUnet_data_path)

print("Files copied")
# Out:
# Files copied

# %% [markdown]
# Visualize the max rotations

# %%
from nilearn import image

image_path = 'results/transformed_results/transformed_images'
label_path = 'results/transformed_results/transformed_labels'
for index in range(len(data_dicts)):
    a, b, c = 0.0, 0.0, 10.0
    img_str = data_dicts[index]['image'].strip("data/imagesTs/").strip(".nii.gz")
    lbl_str = data_dicts[index]['image'].strip("data/imagesTs/").strip("_0000.nii.gz")
    img_path = image_path + "/" + f'{a}_{b}_{c}' + "/"+ img_str + "/" + img_str + f"_rotated_image_{a}_{b}_{c}_0000" + '.nii.gz'
    lbl_path = label_path + "/" + f'{a}_{b}_{c}' + "/"+lbl_str + "/" + lbl_str + f"_rotated_label_{a}_{b}_{c}" + '.nii.gz'
    after_rot = image.load_img(img_path)
    after_rot_label = image.load_img(lbl_path)
    dimension = after_rot.shape

    center = np.divide(dimension,2)
    x_cen = int(np.ceil(center[0]))
    y_cen = int(np.ceil(center[1]))
    z_cen = int(np.ceil(center[2]))

    fig = plt.figure("visualize", (len(data_dicts), 3))
    fig.set_size_inches(10,3)
    plt.subplot(1, 3, 1)
    plt.title(f"Slice through x-center ")
    plt.imshow(get_data(after_rot)[x_cen, :, :])
    plt.subplot(1, 3, 2)
    plt.title(f"Slice through y-center ")
    plt.imshow(get_data(after_rot)[:, y_cen, :])
    plt.subplot(1, 3, 3)
    plt.title(f"Slice through z-center")
    plt.imshow(get_data(after_rot)[:, :, z_cen])
    plt.show()

    fig = plt.figure("labels", (len(data_dicts), 3))
    fig.set_size_inches(10,3)
    plt.subplot(1, 3, 1)
    plt.title(f"Slice through x-center ")
    plt.imshow(get_data(after_rot_label)[x_cen, :, :])
    plt.subplot(1, 3, 2)
    plt.title(f"Slice through y-center ")
    plt.imshow(get_data(after_rot_label)[:, y_cen, :])
    plt.subplot(1, 3, 3)
    plt.title(f"Slice through z-center ")
    plt.imshow(get_data(after_rot_label)[:, :, z_cen])
    plt.show()
